# %% [markdown]
# <a href="https://colab.research.google.com/github/DigoShane/GitHub-ML/blob/main/Grokking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/DigoShane/grokking.git
# Out:
# fatal: destination path 'grokking' already exists and is not an empty directory.

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

# %cd grokking
# Out:
# True
# Tesla T4
# /content/grokking/grokking

# %%
# !pip install torch torchvision matplotlib wandb tqdm numpy

# %%
import os
os.environ["WANDB_MODE"] = "disabled"

# %%
# !python3 cli.py
# Out:
# Device: cuda
# GPU: Tesla T4
# train_inputs.device: cuda:0  shape: torch.Size([4656, 4])
# 100% 100000/100000 [09:15<00:00, 179.96it/s]
